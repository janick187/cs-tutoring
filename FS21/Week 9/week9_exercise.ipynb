# %% [markdown]
# # FCS Tutoring Session 8
#
# This week is all about data visualization, which is a very important and relevant topic as our eyes can draw conclusions from visuals much better than from plain data filled into DataFrames.
#
# Following you have three quite challenging visualization tasks. Happy coding!
#
#
# For any questions please contact me on Slack.
#
# Janick Spirig, 06.05.2021

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
stats = [
         ("Dele", 1, 4, 15,18,5),
         ("Harry Kane", 12, 18, 25,12,23),
         ("Lionel Messi", 45, 32, 40,30,51),
         ("Fabian Schär", 2, 9, 4,12,2),
         ("Kevin De Bruyne", 25, 12, 18,20,16),
         ("Sergio Agüero", 15, 11, 30,32,15),
         ("Cristiano Ronaldo", 40, 42, 38,31,44)
         ]

df = pd.DataFrame(stats, columns=['Name', '2014/2015', '2015/2016', '2016/2017', '2017/2018', '2018/2019'])

# %%
df
# Out:
#                 Name  2014/2015  2015/2016  2016/2017  2017/2018  2018/2019
# 0               Dele          1          4         15         18          5
# 1         Harry Kane         12         18         25         12         23
# 2       Lionel Messi         45         32         40         30         51
# 3       Fabian Schär          2          9          4         12          2
# 4    Kevin De Bruyne         25         12         18         20         16
# 5      Sergio Agüero         15         11         30         32         15
# 6  Cristiano Ronaldo         40         42         38         31         44

# %% [markdown]
# ## Task 1: Line diagram

# %%
def task1(df):
  """
  - Plot the data in df as a line chart. There should be seven dotted lines, one for each row in the df. So in the end each line represents a player.
  - Set the size of the plot to (20,10)
  - Add a legend to the plot
  - Rotate the x-axis labels by 90 degrees
  """

  # your code here
  
task1(df)

# %% [markdown]
# ### How your solution should look like
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Task 2: Grid of plots

# %%
def task2(df):
  """
  - Create a 5x3 grid of plots.
  - Plot each row/player in the df (submitted as parameter) in one of the subplots as a scatterplot. All subplots should share their x and y-axis.
  - Arrange the plots in such a way that they form an X-shape. After finishing you should have a 5x3 grid. For this task your plots should be placed
  where the X are marked here:
    O   X   O
    X   O   X
    O   X   O
    X   O   X
    O   X   O

  The "O" refers to an empty subplot.

  - Add a legend to each of your plots.
  - Give each plot a different color.
  - Set the size of the subplots to figsize=(20,15)
  - Additionaly, draw the data for Cristiano Ronaldo and Lionel Messi in the sixth fourth subplot as lines and fill the area between the lines with the color of your choice.

  --> See the example solution below <--

  """
  # your code here
  
task2(df)

# %% [markdown]
# ## How your solution should look like
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Task 3: Bar plot

# %%
def task3(df):
  """
  - Draw the data of the first three players of the df as a bar plot.
  - In the end your cahrt should contain a total 15 bars where every 3 bars are grouped together representing a football year/season.
  - set the size of the plot to figsize=(15,5)
  - the bars should appear in the colors cyan, orange and blue
  """

  # your code here

task3(df)

# %% [markdown]
# ### How your solution should look like
#
# ![image.png](data:image/png;base64,...)
